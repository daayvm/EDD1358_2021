# %% [markdown]
# <a href="https://colab.research.google.com/github/daayvm/EDD1358_2021/blob/master/JUEGO_VIDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Array2D:

    def __init__(self,rows, cols, value):
        self.__cols = cols
        self.__rows = rows
        self.__array=[[value for x in range(self.__cols)] for y in range(self.__rows)]

    def to_string(self):
        [print("---",end="") for x in range(self.__cols)]
        print("")
        for ren in self.__array:
            print(ren)
        [print("---",end="") for x in range(self.__cols)]
        print("")

    def get_num_rows(self):
        return self.__rows

    def get_num_cols(self):
        return self.__cols

    def get_item(self,row,col):
        return self.__array[row][col]

    def set_item( self , row , col , valor ):
        self.__array[row][col]=valor

    def clearing(self, valor=0):
        for ren in range(self.__rows):
            for col in range(self.__cols):
                self.__array[ren][col]=valor


#----------------------------------------------------------------   


class JuegoVida:
  CelulaViva = 1
  CelulaMuer = 0

  def __init__ (self , renglon, colum , genes, poblacion):
      self.largo = colum
      self.alto = renglon
      self.grid = Array2D( self.alto , self.largo,0 )
      self.grid.clearing(self.CelulaMuer)
      self.generaciones = genes
        
      for celula in poblacion:
        self.grid.set_item(celula[0], celula[1] , self.CelulaViva)

  def imprime_grid(self):
        for r in range(self.grid.get_num_rows()):
            for c in range(self.grid.get_num_cols()):
                if self.grid.get_item(r,c) == 0:
                    print("░░",end="")
                else:
                    print("▓▓",end="")
            print("")
        print("")

  def get_num_rows(self):
    return self.alto
  
  def get_num_cols(self):
    return self.largo  
  
  def configura_gener(self, nueva_gene):
        self.grid.clearing(0)
        for celula in nueva_gene:
            self.grid.set_item(celula[0],celula[1], self.CelulaViva ) 

  def set_celu_muerta(self,row,col):
        self.grid.set_item(row, col, self.CelulaMuer )

  def set_celu_viva(self,row,col): 
        self.grid.set_item(row, col, set.CelulaViva )
  
  def get_is_muerta(self, row, col):
    return self.grid.get_item(col,row) == self.CelulaMuer

  def get_is_viva(self, row, col):
    return self.grid.get_item(col,row) == self.CelulaViva

  def get_num_vecinos(self, row, col):
        limites = self.calcula_vecinos(row,col)
        cont = 0
        for fila in range(limites[0], limites[2]+1):
            for cols in range(limites[1],limites[3]+1):
                if fila == row and cols == col:
                    pass
                else:
                    if self.get_is_viva(fila,cols):
                        cont = cont+1
        return cont

  def calcula_vecinos(self,y,x):
        vecinos = [ y-1 , x-1 , y+1 , x+1]
        if vecinos[0] == -1:
            vecinos[0] == 0
        if vecinos[1] == -1:
            vecinos[1] == 0
        if vecinos[2] == self.alto :
            vecinos[2] = self.alto -1
        if vecinos[3] == self.largo:
            vecinos[3] = self.largo -1
        return vecinos

def evolucionar():
    generaciones = int(input("Generaciones solicitadas: "))
    inicial = [[1,2],[2,1],[2,2],[2,3]]
    juego = JuegoVida(7,7,generaciones,inicial)
    nueva_gene = inicial
    for gene in range(1, generaciones+1):
        vecinos_vivos = 0
        nueva_gene = []
        juego.imprime_grid()
        for row in range(7):
            for col in range(7):
                corde = []
                vecinos_vivos = juego.get_num_vecinos(row,col)
                if juego.get_is_viva(row, col ) == True:
                    if vecinos_vivos == 0 or vecinos_vivos == 1 or vecinos_vivos >=4:
                        pass
                    elif vecinos_vivos == 2 or vecinos_vivos ==3:
                        corde = [row, col]
                        nueva_gene.append(corde)
                if juego.get_is_viva(row, col) == False and vecinos_vivos == 3:
                    corde = [row, col]
                    nueva_gene.append(corde)
        juego.configura_gener(nueva_gene)

evolucionar()
# Out:
# Generaciones solicitadas: 7
# ░░░░░░░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ▓▓▓▓░░▓▓▓▓░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ▓▓░░░░░░▓▓░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ▓▓▓▓░░▓▓▓▓░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
